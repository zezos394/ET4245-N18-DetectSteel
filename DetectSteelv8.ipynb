# %% [markdown]
# #1.Install and import dependencies

# %%
# !pip install ultralytics

# %%
# download pretrain model Yolov8s
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt

# %% [markdown]
# #2.Train Data

# %%
#Mount to drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#Create training yaml file
# %cd /content/drive/MyDrive
# !rm data_N18/dataset.yaml
# !echo 'train: /content/drive/MyDrive/data_N18/data' >> data_N18/dataset.yaml
# !echo 'val: /content/drive/MyDrive/data_N18/data' >> data_N18/dataset.yaml
# !echo 'nc: 1' >> data_N18/dataset.yaml #number of class
# !echo "names: ['thep']" >> data_N18/dataset.yaml #class name:['fire','water']

# %%
#Train data
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/data_N18/dataset.yaml epochs=200 imgsz=640

# %% [markdown]
# #3.Load Your Trained Model

# %%
#Detect
# !yolo task=detect mode=predict model="/content/drive/MyDrive/file_weight_20230612/best.pt" source="/content/drive/MyDrive/data2/180.png"

# %% [markdown]
# #4.Auto Labeling Tool

# %%
# Predict and save prediction as a text file
# Read the image and perform object detection on it
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/file_weight_20230612/best.pt")
image_path = "/content/drive/MyDrive/dataDuc/pic100/9e.jpg"
predictions = model.predict(image_path, save_txt=None)

# Save the predicted text file to disk
with open("/content/drive/MyDrive/dataDuc/pic100/9e.txt", '+w') as file:
      for idx, prediction in enumerate(predictions[0].boxes.xywhn): # change final attribute to desired box format
          cls = int(predictions[0].boxes.cls[idx].item())
          # Write line to file in YOLO label format : cls x y w h
          file.write(f"{cls} {prediction[0].item()} {prediction[1].item()} {prediction[2].item()} {prediction[3].item()}\n")
