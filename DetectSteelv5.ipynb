# %% [markdown]
# #1.Install and import dependencies

# %%
# !pip install torch torchvision torchaudio

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# !pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# #2.Load Model

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s')

# %% [markdown]
# #3.Train Data

# %%
#Mount to drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#Create training yaml file
# %cd /content/drive/MyDrive
# !rm data_N18/dataset.yaml #delete if already exist one
# !echo 'train: /content/drive/MyDrive/data_N18/data' >> data_N18/dataset.yaml
# !echo 'val: /content/drive/MyDrive/data_N18/data' >> data_N18/dataset.yaml
# !echo 'nc: 1' >> data_N18/dataset.yaml #number of class
# !echo "names: ['thep']" >> data_N18/dataset.yaml #class name:['fire','water']

# %%
#Move to train section
# %cd /content/yolov5
#Remember to add your dataset.yaml here

# %%
# !python train.py --img 640 --batch 20 --epochs 200 --data dataset.yaml --weights yolov5s.pt --workers 2

# %% [markdown]
# #4.Load Your Trained Model

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path='/content/yolov5/runs/train/exp2/weights/best.pt', force_reload=True)

# %%
# Add image to test detection
img = "/content/drive/MyDrive/data2/180.png"
results = model(img)

# %%
#show result
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
